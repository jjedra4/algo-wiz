# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
data_path = 'data'

lena = cv2.imread(os.path.join(data_path, 'lena.png'))
mandril = cv2.imread(os.path.join(data_path, 'mandril.jpg'))

# %%
cv2.imwrite('data/mandril.png', mandril)
# Out:
# True

# %%
plt.imshow(mandril)

# %%
cv2.imshow('mandril', mandril)
cv2.waitKey(0)
# Out:
# 2026-03-04 15:34:57.279 python[86726:34562724] +[IMKClient subclass]: chose IMKClient_Legacy
# 2026-03-04 15:34:57.279 python[86726:34562724] +[IMKInputSession subclass]: chose IMKInputSession_Legacy
# 119

# %%
cv2.destroyAllWindows()

# %%
mandiril_png = cv2.imread(os.path.join(data_path, 'mandril.png'))
plt.imshow(mandiril_png)
